# %% [markdown]
# # Solution for Lab 0, Question 1
#
# After reading the problem statement we can begin by reading in the data.
# For this we will be using pd.read_csv()

# %%
import pandas as pd

# %%
df = pd.read_csv('tree_survey_data.csv')

# %% [markdown]
# # First steps
#
#
# So the first thing you should do after loading a dataset in my opinion is to run df.head to just have a look at how the data looks

# %% [markdown]
# ## Data Cleaning
# Let us begin by trying to clean the problematic values in the dataset.

# %%
df.head()
# Out:
#   Surveyor  Latitude  Longitude  Tree Height  Tree Trunk Thickness  \
# 0      Bob      13.0       77.6       284.50                441.70
# 1    Alice      13.1       80.3        29.16                 49.38
# 2    Alice      11.0       77.0        21.55                 42.23
# 3      Bob      13.0       77.6       295.80                522.50
# 4      Bob      11.0       76.9       319.30                474.10
#
#    Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# 0          145.50               48.10                48.30
# 1           23.64                7.82                 7.82
# 2           39.64               13.19                13.23
# 3          177.30               60.70                60.70
# 4          393.80              132.50               133.10
#
#    Middle Sub Leaf Size
# 0                 47.90
# 1                  7.77
# 2                 13.21
# 3                 61.40
# 4                133.30

# %%
df.head(40) # To show more rows
# Out:
#    Surveyor  Latitude  Longitude    Tree Height  Tree Trunk Thickness  \
# 0       Bob      13.0       77.6     284.500000          4.417000e+02
# 1     Alice      13.1       80.3      29.160000          4.938000e+01
# 2     Alice      11.0       77.0      21.550000          4.223000e+01
# 3       Bob      13.0       77.6     295.800000          5.225000e+02
# 4       Bob      11.0       76.9     319.300000          4.741000e+02
# 5     Alice      12.9       77.6      29.110000          4.903000e+01
# 6   Charlie    -187.4     -197.2  999448.883760          2.096861e+02
# 7       Bob      11.0       77.0     300.700000          4.938000e+02
# 8     Alice      11.0       76.9      42.190000          6.108000e+01
# 9     Alice      11.0       76.9      22.880000          4.525000e+01
# 10    Alice      12.9       77.6      31.630000          5.255000e+01
# 11      Bob      11.0       77.0     368.200000          5.830000e+02
# 12  Charlie    -114.9     -311.8    1334.506133         -1.149741e+03
# 13    Alice      13.0       77.6      28.180000          4.960000e+01
# 14    Alice      11.0       77.0      23.440000          4.973000e+01
# 15    Alice      13.0       77.6      38.890000          5.179000e+01
# 16  Charlie    -132.2      268.9     120.685706          1.000201e+06
# 17      Bob      12.9       77.6     327.000000          5.040000e+02
# 18      Bob      11.0       76.9     322.400000          5.278000e+02
# 19  Charlie    -166.4      308.2   -1591.876066                   NaN
# 20      Bob      13.0       77.5     389.700000          5.694000e+02
# 21      Bob      12.9       77.6     332.300000          5.359000e+02
# 22      Bob      12.9       77.6     284.000000          4.606000e+02
# 23      Bob      13.0       77.6     341.000000          5.352000e+02
# 24      Bob      13.1       80.3     295.300000          5.046000e+02
# 25      Bob      13.0       77.6     224.700000          4.164000e+02
# 26  Charlie     187.6     -290.3   -1806.509629          9.993035e+05
# 27    Alice      13.1       80.3      29.730000          4.728000e+01
# 28      Bob      11.0       77.0     280.100000          4.965000e+02
# 29    Alice      13.0       77.6      32.280000          5.277000e+01
# 30  Charlie      34.4     -116.0    -812.058224         -5.436657e+01
# 31      Bob      11.0       77.0     254.400000          4.571000e+02
# 32    Alice      13.1       80.3      35.050000          5.465000e+01
# 20          2.530000e+01
# 21          4.410000e+01
# 22          4.860000e+01
# 23          4.720000e+01
# 24          8.230000e+01
# 25          6.630000e+01
# 26         -1.353653e+03
# 27          7.720000e+00
# 28          1.125000e+02
# 29          5.360000e+00
# 30          1.002360e+06
# 31          1.223000e+02
# 32          1.175000e+01
# 33          8.410000e+01
# 34                   NaN
# 35          1.213000e+01
# 36          4.330000e+00
# 37          1.000033e+06
# 38          6.520000e+01
# 39         -9.913344e+02

# %% [markdown]
# Already I see some interesting patterns in the data..... but a few more commands for a broad overview

# %%
df.describe()
# Out:
#          Latitude    Longitude   Tree Height  Tree Trunk Thickness  \
# count  1010.00000  1010.000000  9.510000e+02          9.560000e+02
# mean     10.46802    64.983663  5.055235e+04          6.085137e+04
# std      55.57346   101.895892  2.189660e+05          2.388328e+05
# min    -198.20000  -389.100000 -2.564974e+03         -3.458169e+03
# 25%      11.00000    77.000000  2.947500e+01          4.901000e+01
# 50%      12.90000    77.600000  2.043000e+02          4.035000e+02
# 75%      13.00000    77.600000  3.160500e+02          5.161000e+02
# max     198.30000   395.800000  1.001305e+06          1.002503e+06
#
#        Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# count    9.630000e+02        9.680000e+02         9.690000e+02
# mean     6.030482e+04        4.749727e+04         5.364310e+04
# std      2.380538e+05        2.128594e+05         2.254715e+05
# min     -3.061405e+03       -2.892034e+03        -2.973306e+03
# 25%      2.183500e+01        7.142500e+00         6.940000e+00
# 50%      1.165000e+02        3.595000e+01         3.270000e+01
# 75%      3.398500e+02        1.136500e+02         1.135000e+02
# max      1.002060e+06        1.001300e+06         1.001851e+06
#
#        Middle Sub Leaf Size
# count          9.540000e+02
# mean           6.078830e+04
# std            2.390977e+05
# min           -4.375579e+03
# 25%            7.710000e+00
# 50%            3.965000e+01
# 75%            1.143000e+02
# max            1.002360e+06

# %%
df.isna().sum() # Raw number of nans
# Out:
# Surveyor                 0
# Latitude                 0
# Longitude                0
# Tree Height             59
# Tree Trunk Thickness    54
# Tree Leaf Size          47
# Left Sub Leaf Size      42
# Right Sub Leaf Size     41
# Middle Sub Leaf Size    56
# dtype: int64

# %%
df.isna().mean() # Percentage nans
# Out:
# Surveyor                0.000000
# Latitude                0.000000
# Longitude               0.000000
# Tree Height             0.058416
# Tree Trunk Thickness    0.053465
# Tree Leaf Size          0.046535
# Left Sub Leaf Size      0.041584
# Right Sub Leaf Size     0.040594
# Middle Sub Leaf Size    0.055446
# dtype: float64

# %%
# Showing the rows with at least one nan

df[df.isna().any(axis=1)]
# Out:
#      Surveyor  Latitude  Longitude   Tree Height  Tree Trunk Thickness  \
# 19    Charlie    -166.4      308.2 -1.591876e+03                   NaN
# 26    Charlie     187.6     -290.3 -1.806510e+03          9.993035e+05
# 34    Charlie    -184.0       42.4 -2.534125e+03         -9.108018e+02
# 37    Charlie    -144.8      219.2           NaN          9.995542e+05
# 39    Charlie    -168.1     -233.1           NaN         -1.728390e+03
# ...       ...       ...        ...           ...                   ...
# 994   Charlie     116.0     -280.7 -9.760200e+02          1.000851e+06
# 999   Charlie     -80.7      386.0  1.000572e+06          1.000504e+06
# 1000  Charlie    -104.5     -215.1 -6.115754e+02         -5.740890e+02
# 1003  Charlie    -164.7      155.2  3.353173e+02          9.989602e+05
# 1009  Charlie    -127.5     -110.7           NaN         -1.960780e+03
#
#       Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# 19      1.001686e+06        1.001131e+06         9.993599e+05
# 26     -1.271730e+03                 NaN         6.352455e+02
# 34      9.999214e+05       -5.054472e+02                  NaN
# 37     -1.482229e+02       -7.259612e+02                  NaN
# 39      9.997378e+05                 NaN        -2.783103e+02
# ...              ...                 ...                  ...
# 994     4.457599e+02                 NaN                  NaN
# 999     1.000252e+06        1.346397e+02                  NaN
# 1000             NaN                 NaN        -3.390883e+02
# 1003    5.382116e+02                 NaN        -1.070321e+03
# 1009   -6.462423e+02       -9.691929e+02         1.000508e+06
#
#       Middle Sub Leaf Size
# 19                     NaN
# 26           -1.353653e+03
# 34                     NaN
# 37            1.000033e+06
# 39           -9.913344e+02
# ...                    ...
# 994           1.001346e+06
# 999           1.002269e+06
# 1000          1.000330e+06
# 1003                   NaN
# 1009         -3.306800e+01
#
# [163 rows x 9 columns]

# %% [markdown]
# So now it should be obvious what We observed earlier....
# All the nan rows have the surveyor as charlie...
# So let us try to look at the data of charlie

# %%
df[df['Surveyor'] == "Charlie"].head(50)
# Out:
#     Surveyor  Latitude  Longitude   Tree Height  Tree Trunk Thickness  \
# 6    Charlie    -187.4     -197.2  9.994489e+05          2.096861e+02
# 12   Charlie    -114.9     -311.8  1.334506e+03         -1.149741e+03
# 16   Charlie    -132.2      268.9  1.206857e+02          1.000201e+06
# 19   Charlie    -166.4      308.2 -1.591876e+03                   NaN
# 26   Charlie     187.6     -290.3 -1.806510e+03          9.993035e+05
# 30   Charlie      34.4     -116.0 -8.120582e+02         -5.436657e+01
# 34   Charlie    -184.0       42.4 -2.534125e+03         -9.108018e+02
# 37   Charlie    -144.8      219.2           NaN          9.995542e+05
# 39   Charlie    -168.1     -233.1           NaN         -1.728390e+03
# 45   Charlie    -142.7       19.9  1.000542e+06          1.000662e+06
# 46   Charlie     142.6      311.4 -2.995494e+02                   NaN
# 47   Charlie    -169.7      217.1           NaN         -1.770114e+02
# 54   Charlie     180.8      -39.0  1.030782e+02          1.000922e+06
# 57   Charlie    -173.9      -43.8  3.049627e+02          1.001831e+06
# 58   Charlie     -20.2     -232.2           NaN         -9.400902e+02
# 75   Charlie    -102.7     -283.3  9.998239e+05         -1.671308e+03
# 80   Charlie     -30.2     -132.6           NaN          9.988609e+05
# 83   Charlie    -126.8     -117.1 -9.934513e+02         -8.085493e+02
# 92   Charlie    -179.2     -182.6           NaN                   NaN
# 93   Charlie      82.6     -131.8  9.987548e+05          6.040974e+02
# 98   Charlie    -137.8     -373.7 -1.344983e+03                   NaN
# 100  Charlie     182.6      158.0  9.992980e+05                   NaN
# 111  Charlie     104.2      388.4  3.576196e+02          1.001361e+06
# 114  Charlie    -139.9     -153.8 -2.344928e+03         -2.998345e+03
# 117  Charlie     -23.2      214.7           NaN                   NaN
# 120  Charlie      61.5       -4.1 -3.744087e+02          1.000688e+06
# 123  Charlie     143.5      -72.8           NaN          5.668547e+02
# 128  Charlie     -78.2      -30.0           NaN         -2.704622e+03
# 149             NaN       -4.871672e+02         9.999876e+05
# 152   -8.792098e+02                 NaN                  NaN
# 159             NaN       -4.112604e+02        -5.678078e+02
# 163             NaN       -2.185922e+03         1.000243e+06
# 167    8.955073e+02                 NaN                  NaN
# 169    1.001042e+06       -2.848110e+03        -1.864430e+03
# 174    6.218737e+02                 NaN         9.998998e+05
# 180    1.000781e+06       -7.931347e+02        -3.542014e+01
# 182             NaN        1.001189e+06         9.991492e+05
# 189   -5.326068e+02       -2.889703e+03        -3.743900e+02
# 191    9.606132e+02       -3.223629e+02                  NaN
# 193   -1.527701e+03        1.001300e+06                  NaN
# 198   -1.998570e+03       -6.113528e+02         1.000995e+06
# 200             NaN        1.801373e+03                  NaN
# 202   -1.662691e+03       -8.345084e+02         1.000853e+06
# 208   -3.287449e+01        9.035207e+02                  NaN
# 216   -1.860438e+03        9.993995e+05        -1.361675e+03
# 222    1.000233e+06       -5.217667e+02         1.000693e+06
# 224   -1.751167e+03       -1.479354e+03        -2.315438e+03
#
#      Middle Sub Leaf Size
# 6            1.000179e+06
# 12           9.994263e+05
# 16           9.998560e+05
# 19                    NaN
# 26          -1.353653e+03
# 30           1.002360e+06
# 34                    NaN
# 37           1.000033e+06
# 39          -9.913344e+02
# 45           1.060800e+03
# 46                    NaN
# 47                    NaN
# 54                    NaN
# 57           1.000195e+06
# 58                    NaN
# 75           1.001297e+06
# 80          -2.661581e+03
# 83           1.000314e+06
# 92          -1.449650e+03
# 93          -2.477506e+03
# 98           5.399509e+02
# 100         -1.589160e+03
# 111                   NaN
# 114                   NaN
# 117          9.996169e+05
# 120          9.994027e+05
# 123          1.001112e+06
# 128                   NaN
# 130                   NaN
# 137         -5.089961e+02
# 141         -2.618823e+03
# 149                   NaN
# 152                   NaN
# 159         -1.552924e+03
# 163          1.805669e+03
# 167          2.620166e+02
# 169          9.989817e+05
# 174         -3.946904e+03
# 180         -2.805717e+02
# 182         -4.028334e+02
# 189          1.000510e+06
# 191         -9.230724e+02
# 193         -2.360971e+02
# 198          1.803387e+02
# 200          9.988180e+05
# 202         -6.975419e+02
# 208          2.367171e+02
# 216          1.001777e+06
# 222         -1.085963e+03
# 224          1.001163e+06

# %% [markdown]
# So all charlie values are nonsensical in my opinion... negative lengths nans very large and very small values....
#
# Looking at such data in real life you would probably assume that it is faulty so it is best to drop it.

# %%
# So now we will just drop all the charlie rows
df = df.drop(df[df['Surveyor'] == "Charlie"].index)
df.head()
# Out:
#   Surveyor  Latitude  Longitude  Tree Height  Tree Trunk Thickness  \
# 0      Bob      13.0       77.6       284.50                441.70
# 1    Alice      13.1       80.3        29.16                 49.38
# 2    Alice      11.0       77.0        21.55                 42.23
# 3      Bob      13.0       77.6       295.80                522.50
# 4      Bob      11.0       76.9       319.30                474.10
#
#    Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# 0          145.50               48.10                48.30
# 1           23.64                7.82                 7.82
# 2           39.64               13.19                13.23
# 3          177.30               60.70                60.70
# 4          393.80              132.50               133.10
#
#    Middle Sub Leaf Size
# 0                 47.90
# 1                  7.77
# 2                 13.21
# 3                 61.40
# 4                133.30

# %%
df.head(30)
# Out:
#    Surveyor  Latitude  Longitude  Tree Height  Tree Trunk Thickness  \
# 0       Bob      13.0       77.6       284.50                441.70
# 1     Alice      13.1       80.3        29.16                 49.38
# 2     Alice      11.0       77.0        21.55                 42.23
# 3       Bob      13.0       77.6       295.80                522.50
# 4       Bob      11.0       76.9       319.30                474.10
# 5     Alice      12.9       77.6        29.11                 49.03
# 7       Bob      11.0       77.0       300.70                493.80
# 8     Alice      11.0       76.9        42.19                 61.08
# 9     Alice      11.0       76.9        22.88                 45.25
# 10    Alice      12.9       77.6        31.63                 52.55
# 11      Bob      11.0       77.0       368.20                583.00
# 13    Alice      13.0       77.6        28.18                 49.60
# 14    Alice      11.0       77.0        23.44                 49.73
# 15    Alice      13.0       77.6        38.89                 51.79
# 17      Bob      12.9       77.6       327.00                504.00
# 18      Bob      11.0       76.9       322.40                527.80
# 20      Bob      13.0       77.5       389.70                569.40
# 21      Bob      12.9       77.6       332.30                535.90
# 22      Bob      12.9       77.6       284.00                460.60
# 23      Bob      13.0       77.6       341.00                535.20
# 24      Bob      13.1       80.3       295.30                504.60
# 25      Bob      13.0       77.6       224.70                416.40
# 27    Alice      13.1       80.3        29.73                 47.28
# 28      Bob      11.0       77.0       280.10                496.50
# 29    Alice      13.0       77.6        32.28                 52.77
# 31      Bob      11.0       77.0       254.40                457.10
# 32    Alice      13.1       80.3        35.05                 54.65
# 33      Bob      13.0       77.6       281.50                498.60
# 35    Alice      11.0       76.9        30.34                 51.03
# 36    Alice      13.0       77.6        31.63                 53.63
#
#     Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# 0           145.50               48.10                48.30
# 1            23.64                7.82                 7.82
# 2            39.64               13.19                13.23
# 3           177.30               60.70                60.70
# 4           393.80              132.50               133.10
# 5            13.29                4.54                 4.56
# 7           393.80              130.60               131.00
# 8            32.61               10.83                10.78
# 9            38.32               12.81                12.77
# 10           16.78                5.68                 5.61
# 11          394.70              132.30               132.60
# 13           19.14                6.49                 6.41
# 14           39.02               13.13                13.04
# 15           10.50                3.49                 3.64
# 17          183.60               61.10                61.70
# 18          390.60              129.10               130.10
# 20           77.90               24.90                24.40
# 21          130.90               43.30                44.10
# 22          145.20               48.80                48.80
# 23          140.50               47.50                48.10
# 24          255.50               82.50                83.40
# 25          197.20               65.80                65.70
# 27           23.12                7.65                 7.64
# 28          341.10              113.60               113.80
# 29           15.90                5.36                 5.39
# 31          368.60              122.00               122.30
# 32           34.88               11.74                11.69
# 33          248.50               84.40                83.70
# 35           36.47               12.10                12.02
# 36           12.65                4.32                 4.29
#
#     Middle Sub Leaf Size
# 0                  47.90
# 1                   7.77
# 2                  13.21
# 3                  61.40
# 4                 133.30
# 5                   4.59
# 7                 130.80
# 8                  10.81
# 9                  12.79
# 10                  5.72
# 11                131.70
# 13                  6.51
# 14                 13.19
# 15                  3.48
# 17                 60.70
# 18                130.00
# 20                 25.30
# 21                 44.10
# 22                 48.60
# 23                 47.20
# 24                 82.30
# 25                 66.30
# 27                  7.72
# 28                112.50
# 29                  5.36
# 31                122.30
# 32                 11.75
# 33                 84.10
# 35                 12.13
# 36                  4.33

# %% [markdown]
# Even here I see quite a clear pattern.... The values of alice and bob seem to be off by a factor of 10....
# But let us investigate it further.
# It naturally leads us to our next step

# %% [markdown]
# ## Data Normalization

# %% [markdown]
# For this we will split the dataframe into an alice and a bob dataframe

# %%
df_alice = df[df['Surveyor'] == "Alice"]
df_bob = df[df['Surveyor'] == "Bob"]


df_alice.describe()
# Out:
#          Latitude   Longitude  Tree Height  Tree Trunk Thickness  \
# count  390.000000  390.000000   390.000000            390.000000
# mean    12.283846   77.953333    30.186436             50.136974
# std      0.964629    1.267825     5.043012              4.949416
# min     10.900000   76.900000    15.890000             33.380000
# 25%     11.000000   77.000000    26.750000             46.845000
# 50%     13.000000   77.600000    30.145000             49.785000
# 75%     13.000000   77.600000    33.570000             53.387500
# max     13.200000   80.400000    44.020000             65.300000
#
#        Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# count      390.000000          390.000000           390.000000
# mean        26.362667            8.787641             8.790256
# std         11.122948            3.714244             3.713446
# min          6.490000            2.020000             2.030000
# 25%         15.680000            5.260000             5.295000
# 50%         25.635000            8.545000             8.550000
# 75%         36.962500           12.270000            12.282500
# max         48.540000           16.090000            16.010000
#
#        Middle Sub Leaf Size
# count            390.000000
# mean               8.788308
# std                3.717144
# min                2.040000
# 25%                5.250000
# 50%                8.565000
# 75%               12.267500
# max               16.100000

# %%
df_bob.describe()
# Out:
#          Latitude   Longitude  Tree Height  Tree Trunk Thickness  \
# count  416.000000  416.000000   416.000000            416.000000
# mean    12.179087   77.809135   302.988702            502.165865
# std      0.988839    1.186597    50.484427             51.051521
# min     10.900000   76.900000   116.100000            365.300000
# 25%     11.000000   77.000000   269.075000            465.300000
# 50%     12.900000   77.600000   302.800000            504.500000
# 75%     13.000000   77.600000   337.100000            536.375000
# max     13.200000   80.300000   421.900000            656.400000
#
#        Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# count      416.000000          416.000000           416.000000
# mean       267.455529           89.090385            89.108654
# std        113.087069           37.685971            37.677536
# min         59.200000           20.500000            20.300000
# 25%        157.825000           52.550000            52.675000
# 50%        260.550000           86.400000            86.150000
# 75%        378.425000          125.725000           125.800000
# max        478.900000          161.600000           161.700000
#
#        Middle Sub Leaf Size
# count            416.000000
# mean              89.112019
# std               37.688625
# min               20.000000
# 25%               52.600000
# 50%               86.450000
# 75%              125.850000
# max              160.900000

# %%
df_alice["Tree Height"].hist(bins=40)
# Out:
# <Axes: >

# %%
df_bob["Tree Height"].plot.hist(bins=40)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# So the above two seem very similar in distribution as well....
#
# So to normalise I will just multiply all the alice rows by 10

# %%
df.head()
# Out:
#   Surveyor  Latitude  Longitude  Tree Height  Tree Trunk Thickness  \
# 0      Bob      13.0       77.6       284.50                441.70
# 1    Alice      13.1       80.3        29.16                 49.38
# 2    Alice      11.0       77.0        21.55                 42.23
# 3      Bob      13.0       77.6       295.80                522.50
# 4      Bob      11.0       76.9       319.30                474.10
#
#    Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# 0          145.50               48.10                48.30
# 1           23.64                7.82                 7.82
# 2           39.64               13.19                13.23
# 3          177.30               60.70                60.70
# 4          393.80              132.50               133.10
#
#    Middle Sub Leaf Size
# 0                 47.90
# 1                  7.77
# 2                 13.21
# 3                 61.40
# 4                133.30

# %%
num_columns = ["Tree Height", "Tree Trunk Thickness", "Tree Leaf Size", "Left Sub Leaf Size", "Right Sub Leaf Size", "Middle Sub Leaf Size"]

# %%
df.loc[df["Surveyor"] == "Alice", num_columns] = df.loc[df["Surveyor"] == "Alice", num_columns] * 10

# %%
df.head()
# Out:
#   Surveyor  Latitude  Longitude  Tree Height  Tree Trunk Thickness  \
# 0      Bob      13.0       77.6        284.5                 441.7
# 1    Alice      13.1       80.3        291.6                 493.8
# 2    Alice      11.0       77.0        215.5                 422.3
# 3      Bob      13.0       77.6        295.8                 522.5
# 4      Bob      11.0       76.9        319.3                 474.1
#
#    Tree Leaf Size  Left Sub Leaf Size  Right Sub Leaf Size  \
# 0           145.5                48.1                 48.3
# 1           236.4                78.2                 78.2
# 2           396.4               131.9                132.3
# 3           177.3                60.7                 60.7
# 4           393.8               132.5                133.1
#
#    Middle Sub Leaf Size
# 0                  47.9
# 1                  77.7
# 2                 132.1
# 3                  61.4
# 4                 133.3

# %% [markdown]
# Now I think we have finally gotten the data into a mutually comparable form So we Can start looking for relationships between the different quantities.

# %% [markdown]
# # Analysis of Relationships

# %% [markdown]
# ## Distribution of Columns

# %%
df["Tree Height"].hist(bins=40)
# Out:
# <Axes: >

# %%
df["Tree Trunk Thickness"].hist(bins=40)
# Out:
# <Axes: >

# %%
df["Tree Leaf Size"].hist(bins=40)
# Out:
# <Axes: >

# %% [markdown]
# Looking at the histogram..... the first two are gaussian but the third one is quite interesting. It looks like it comes from maybe a combination of three distributions.

# %% [markdown]
# ## Relationship between Columns

# %%
df.plot.scatter(y='Tree Height', x="Tree Trunk Thickness")
# Out:
# <Axes: xlabel='Tree Trunk Thickness', ylabel='Tree Height'>

# %% [markdown]
# So the Tree Height and Tree Trunk Thickness are very strongly correlated

# %%
# So to help with coloring we will add a categorical column for the surveyor with numbers

df["Surveyor_code"] = df["Surveyor"].astype("category").cat.codes

# %%
df.plot.scatter(x="Tree Height", y="Tree Trunk Thickness", c="Surveyor_code", colormap="viridis")
# Out:
# <Axes: xlabel='Tree Height', ylabel='Tree Trunk Thickness'>

# %%
df.plot.scatter(x="Tree Height", y = "Tree Leaf Size", c="Surveyor_code", colormap="viridis")
# Out:
# <Axes: xlabel='Tree Height', ylabel='Tree Leaf Size'>

# %% [markdown]
# Here the pattern does not seem too clear as of now

# %%
df.plot.scatter(x="Tree Trunk Thickness", y="Tree Leaf Size", c="Surveyor_code", colormap="viridis")
# Out:
# <Axes: xlabel='Tree Trunk Thickness', ylabel='Tree Leaf Size'>

# %% [markdown]
# ## Adding Location Information

# %% [markdown]
# Now let us investigate the location based columns

# %%
df.plot.scatter(y="Longitude", x='Latitude', c="Surveyor_code", colormap="viridis")
# Out:
# <Axes: xlabel='Latitude', ylabel='Longitude'>

# %% [markdown]
# So there seem to be three locations we are working in and it may be interesting to treat them differently

# %%
# Location as A if latitude < 12, B if longitude > 79 and C otherwise

df["Location"] = "C"
df.loc[df["Latitude"] < 12, "Location"] = "A"
df.loc[df["Longitude"] > 79, "Location"] = "B"

# %%
# To help with colouring also add a location code column


df["Location_code"] = df["Location"].astype("category").cat.codes

# %% [markdown]
# Let us make the above plots again but with the location as a colour

# %%
df.plot.scatter(x="Tree Trunk Thickness", y="Tree Height", c="Location_code", colormap="viridis")
# Out:
# <Axes: xlabel='Tree Trunk Thickness', ylabel='Tree Height'>

# %%
df.plot.scatter(x="Tree Trunk Thickness", y="Tree Leaf Size", c="Location_code", colormap="viridis")
# Out:
# <Axes: xlabel='Tree Trunk Thickness', ylabel='Tree Leaf Size'>

# %%
df.plot.scatter(x="Tree Height", y = "Tree Leaf Size", c="Location_code", colormap="viridis")
# Out:
# <Axes: xlabel='Tree Height', ylabel='Tree Leaf Size'>

# %% [markdown]
# So from the above histogram it is quite clear that the tree leaf size depends on height (and thickness) differently depending on the location.
# In two of the location it decreaces with height yet in one of the locations it actually increaces with height

# %% [markdown]
# Now let us also try and see the relationship between tree leaf size and the sub leaf sizes.
#
#
# I have a strong prior that all of them are one third the leaf size so let us test that first

# %%
ratio_l = df["Left Sub Leaf Size"] / df["Tree Leaf Size"]
ratio_r = df["Right Sub Leaf Size"] / df["Tree Leaf Size"]
ratio_m = df["Middle Sub Leaf Size"] / df["Tree Leaf Size"]


ratio_l.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ratio_r.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ratio_m.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# All of the above are actually quite close to 0.33 so that means our hypothesis is roughly correct

# %% [markdown]
# You guys can try to investigate a bit about left, right and middle tree leaf size against thickness, location and height but I will skip that here. (There might be something interesting there maybe... Try to have a look)

# %% [markdown]
# # The Final Question

# %% [markdown]
# If you struggled withe the previous parts of the lab then don't worry. It was probably because you guys were using pandas for the first time and are not familiar with data analysis at this moment.
# It will definitely become easier to think about with time.
#
# This question on the other hand is something that I think is genuinely a bit difficult. And I was very happy to see so many different ways people solved it.
#
# So I will outline one of the solution methods here. I have also described two others .But if you have any other way to solve it I'd love to have a look at it as well.

# %% [markdown]
# ## Sol 1
#
# We can think that leaf X grows first and then Y and Z copy it
#
# So it would be reasonable to model
#
#
# $$Y = X + \sigma_{1}$$
#
# $$Z = X + \sigma_{2}$$
#
# Where $\sigma_{1}$ and $\sigma_{2}$ is independent gaussian noise
#
#
# So now
#
#
#
# $$X - Y = \sigma_{1} 	\sim \mathcal{N}(0, \sigma)$$
#
# $$Z - X = \sigma_{2} 	\sim \mathcal{N}(0, \sigma)$$
#
#
# $$Y - Z = \sigma_{1} - \sigma_{2} 	\sim \mathcal{N}(0, 2 \sigma)$$

# %% [markdown]
# So the difference of the two leaves that are not the original will have a greater standard deviation

# %%
diff_1 = df["Left Sub Leaf Size"] - df["Right Sub Leaf Size"]
diff_1.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
diff_2 = df["Left Sub Leaf Size"] - df["Middle Sub Leaf Size"]
diff_2.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
diff_3 = df["Middle Sub Leaf Size"] - df["Right Sub Leaf Size"]
diff_3.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Since the third distribution very clearly has a greater standard deviation the left leaf will be the original

# %% [markdown]
# # Alternative solution methods
#
# Some that I saw
#
#
# If you think about it for a bit... The chances of the original being "In the middle" is actually greater than one third. (If you assume the noise is as likely to be positive as it is to be negative). This is not a general solution method (Unlike the other two) because it does assume something about the distribution that may not be true.
#
#
#
#
# Another solution that is even more robust would be to check the fact that
#
#
# X - Y is independent to X - Z
#
#
# Here we do not make any assumptions about the distribution of the noise either
